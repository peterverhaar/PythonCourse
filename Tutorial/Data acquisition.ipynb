# %% [markdown]
# < [Regular expressions](Regular%20expressions.html) | [Table of contents](index.html) | [NLTK](NLTK.html) >

# %% [markdown]
# # Data acquisition
#
# Data science projects typically start with the acquisition of data. In many cases, such data sets consist of secondary data made available by commercial or non-commercial organisations. This part of the tutorial explains how you can obtain such online data sets.
#
# ## Direct downloads
#
# If the resources that you are interested in are available directly via the web (i.e. via HTTP or HTTPS), you can download these files by making use of the `requests` library. As is the case for all libraries, the `requests` library needs to be imported before you can use it.

# %%
import requests

# %% [markdown]
# To download data from a certain web address, you can make a GET request. In Python, such a request can be sent using the `get()` method in `requests`, as demonstrated below. Evidently, it is important that you are online when you run the code below.

# %%
response = requests.get( 'http://www.universiteitleiden.nl')

# %% [markdown]
# This method results in a so-called Response object. It is an object which represents information about the downloaded web resource. In the example above, the result of the method is assigned to a variable named `response`.
#
# Once this Response object has been created successfully, you can produce various pieces of information about the resource that was downloaded. The variable `status_code`, for instance, indicates the status code that was returned by the server. The status code 200 indicates that the download was successful and the infamous status code 404 indicates that the file was not found.
#
# In the status code is indeed 200, the `text` variable of the Response object contains full contents of the downloaded website. If you want to make sure that the contents are stored in a specific character encoding scheme, it is advisable to specify this explicitly using the `encoding` variable.
#
# When you run the code that is given below, the contents of the webpage that is specified at the beginning (or more specifically, the HTML code that was created to build the webpage) becomes available as a string, assigned to the variable named `contents`.

# %%
import requests

response = requests.get('http://www.universiteitleiden.nl')
print( response.status_code )

if response.status_code == 200:
    response.encoding = 'utf-8' 
    print (response.text)

# %% [markdown]
# Using the `requests` library, you can basically download any type of file from the web, as long as it is retrievable via HTTP(s). The code below, for instance, downloads a specific text from the Project Gutenberg website.

# %%
url = "http://www.gutenberg.org/files/98/98-0.txt"

response = requests.get(url)

if response:
    response.encoding = 'utf-8' 
    print (response.text)

# %% [markdown]
# Note that the `if` keyword in the code above does not explicitly test whether the response code is 200. The Response object, which is created when you use the `get()` method from requests, automatically returns `True` when the status code is 200.
#
# The `requests` library can also be used to retrieve data that can b accessed via an API.

# %% [markdown]
# ## Acquiring data via APIs
#
# Organisations which aim to make their data available for reuse often do this through an Application Programming Interface (API). An API, simply put, is a software application which can process online requests for information. It enables organisations to share some of the data that they have in a strucured format, so that these other external parties can make use of these data in new applications.
#
# The communication between the sender and the recipient of such requests needs to take place according to a specific protocol; the requests need to formulated according to certain rules.
#
# For many APIs, you need to create an access key before you can send requests. This is the case, for instance, for the Twitter API. There are also many APIs which are fully open, however, such as the Wikipedia API. You can send request to this API without having to provide an access key.
#
# To find information about Wikipedia pages via the Wikipedia API, for instance, you need to send a number of parameters to the endpoint of the API, which is available at [https://en.wikipedia.org/w/api.php](https://en.wikipedia.org/w/api.php). You need to provide values for the following parameters:
#
# `
# action = opensearch
# search = [search term]
# limit = [number]
# format = [json or xml ]
# `
#
# The search term, to be provided after ‘search’, is the word that must occur in the title of the Wikipedia page. If the ‘limit’ parameter is omitted, the API will return 10 results by default.
#
# The following API call returns 20 Wikipedia pages whose titles contain the word ‘Leiden’. The call returns the requested data in the JSON format.
#
# [https://en.wikipedia.org/w/api.php?action=opensearch&search=Leiden&limit=20&namespace=0&format=json](https://en.wikipedia.org/w/api.php?action=opensearch&search=Leiden&limit=20&namespace=0&format=json)
#
# The `json()` method parses the JSON data.

# %%
import requests


baseUrl = 'https://en.wikipedia.org/w/api.php?action=opensearch'


search= 'leiden' 
limit = 20 
format= 'json'


apiCall = '{}&search={}&limit={}&format={}'.format( baseUrl , search , limit, format )
print(apiCall)


response = requests.get( apiCall )
wikiResults = response.json()


for i in range( 0 , len(wikiResults[1]) ):
    print( 'Title: ' + wikiResults[1][i] )
    print( 'Tagline: ' + wikiResults[2][i] )
    print( 'Url: ' + wikiResults[3][i] + '\n')
# Out:
# https://en.wikipedia.org/w/api.php?action=opensearch&search=leiden&limit=20&format=json
# <class 'list'>
# Title: Leiden
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden
#
# Title: Leiden University
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_University
#
# Title: Leiden University Library
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_University_Library
#
# Title: Leidenfrost effect
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leidenfrost_effect
#
# Title: Leiden Law School
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Law_School
#
# Title: Leiden International Film Festival
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_International_Film_Festival
#
# Title: Leiden Observatory
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Observatory
#
# Title: Leiden Centraal railway station
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Centraal_railway_station
#
# Title: Leiden Draft
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Draft
#
# Title: Leiden University Medical Center
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_University_Medical_Center
#
# Title: Leidenheimer Baking Company
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leidenheimer_Baking_Company
#
# Title: Leiden Bio Science Park
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Bio_Science_Park
#
# Title: Leiden Glossary
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Glossary
#
# Title: Leiden Open Variation Database
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Open_Variation_Database
#
# Title: Leiden Aratea
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Aratea
#
# Title: Leiden Conventions
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Conventions
#
# Title: Leiden gunpowder disaster
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_gunpowder_disaster
#
# Title: Leiden Riddle
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Riddle
#
# Title: Leiden scale
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_scale
#
# Title: Leiden Classical
# Tagline:
# Url: https://en.wikipedia.org/wiki/Leiden_Classical

# %% [markdown]
# ## Webscraping
#
# When a website does not offer access to its structured data via a well-defined API, it may be an option to acquire the data that can be viewed on a site by making use of web scraping. It is a process in which a computer program tries to process the contents of given webpage, and to extract the data values that are needed. The function of a Web scraping application can be compared to that of a web crawler or a bot. The aim of such an application is generally to copy information on a web page and to paste it into a local database.
#
# One of the libraries that you can use in Python for scraping online resources is `Beautiful Soup`.
#
# To scrape webpages, you firstly need to download them. This can be done using the code that was explained above. Once you have obtained the contents of a webpage, in the form of an HTML document, you can process its contents effectively by transforming it into a BeautifulSoup object. This object has a `find_all()` function, which you can use to find all occurrences of a specific HTML tag. To extract all the links on a webpage, for example, you need to extract all the `a` tags which have the `href` attribute.
#
# The code below scrapes data from a page on Project Gutenberg. It extract all the titles and the urls of the books which are listed on Project Gutenberg’s Philosophy Bookshelf)

# %%
from bs4 import BeautifulSoup
import requests
import re

## Project Gutenberg Bookshelves can be found at 
## https://www.gutenberg.org/wiki/Category:Bookshelf
url = 'https://www.gutenberg.org/wiki/Philosophy_(Bookshelf)'
response = requests.get( url )

soup = BeautifulSoup( response.text ,"lxml")

links = soup.find_all("a")

for l in links:
    linktext = l.string
    url = l.get("href")

    if re.search('gutenberg' , str(url) , re.IGNORECASE):

        url = re.sub( r'^[/]*' , '' , url )
        print(f"{linktext}: {url}")
# Out:
# Initiation into Philosophy: www.gutenberg.org/ebooks/9304
# An Introduction to Philosophy: www.gutenberg.org/ebooks/16406
# The Approach to Philosophy: www.gutenberg.org/ebooks/25110
# A Short History of Greek Philosophy: www.gutenberg.org/ebooks/20500
# Guide to Stoicism: www.gutenberg.org/ebooks/7514
# Sextus Empiricus and Greek Scepticism: www.gutenberg.org/ebooks/17556
# History of Modern Philosophy From Nicolas of Cusa to the Present Time: www.gutenberg.org/ebooks/11100
# Some Turns of Thought in Modern Philosophy: Five Essays: www.gutenberg.org/ebooks/16712
# Modern French Philosophy: a Study of the Development Since Comte: www.gutenberg.org/ebooks/5246
# The Theological Tractates and The Consolation of Philosophy: www.gutenberg.org/ebooks/13316
# Literary and Philosophical Essays: French, German and Italian: www.gutenberg.org/ebooks/5637
# Also sprach Zarathustra: www.gutenberg.org/ebooks/7205
# Thus Spake Zarathustra: www.gutenberg.org/ebooks/1998
# Rudolph Eucken: a philosophy of life: www.gutenberg.org/ebooks/14357
# The Philosophy of Despair: www.gutenberg.org/ebooks/4754
# The Republic: www.gutenberg.org/ebooks/1497
# The Categories: www.gutenberg.org/ebooks/2412
# The Critique of Pure Reason: www.gutenberg.org/ebooks/4280
# Kritik der reinen Vernunft (Erste Fassung 1781): www.gutenberg.org/ebooks/6342
# Kritik der reinen Vernunft Zweite hin und wieder verbesserte Auflage (1787): www.gutenberg.org/ebooks/6343
# A Pluralistic Universe: Hibbert Lectures at Manchester College on the Present Situation in Philosophy: www.gutenberg.org/ebooks/11984
# Mind and Motion and Monism: www.gutenberg.org/ebooks/22283
# The Problems of Philosophy: www.gutenberg.org/ebooks/5827
# Mysticism and Logic and Other Essays: www.gutenberg.org/ebooks/25447
# Ontology or the Theory of Being: www.gutenberg.org/ebooks/35722
# Theaetetus: www.gutenberg.org/ebooks/1726
# Discours de la méthode: www.gutenberg.org/ebooks/13846
# Discourse on the Method of Rightly Conducting One's Reason and of Seeking Truth in the Sciences: www.gutenberg.org/ebooks/59
# audiobook: www.gutenberg.org/ebooks/19796
# The Selections from the Principles of Philosophy: www.gutenberg.org/ebooks/4391
# A Treatise Concerning the Principles of Human Knowledge: www.gutenberg.org/ebooks/4723
# Three Dialogues Between Hylas and Philonous: www.gutenberg.org/ebooks/4724
# An Enquiry Concerning Human Understanding: www.gutenberg.org/ebooks/9662
# A Treatise of Human Nature: www.gutenberg.org/ebooks/4705
# Improvement of the Understanding: www.gutenberg.org/ebooks/1016
# The Critique of Pure Reason: www.gutenberg.org/ebooks/4280
# Kritik der reinen Vernunft (Erste Fassung 1781): www.gutenberg.org/ebooks/6342
# Kritik der reinen Vernunft Zweite hin und wieder verbesserte Auflage (1787): www.gutenberg.org/ebooks/6343
# Auguste Comte and Positivism: www.gutenberg.org/ebooks/16833
# The Problems of Philosophy: www.gutenberg.org/ebooks/5827
# Mysticism and Logic and Other Essays: www.gutenberg.org/ebooks/25447
# Our Knowledge of the External World as a Field for Scientific Method in Philosophy: www.gutenberg.org/ebooks/37090
# Essays Towards a Theory of Knowledge: www.gutenberg.org/ebooks/23422
# A Pluralistic Universe: Hibbert Lectures at Manchester College on the Present Situation in Philosophy: www.gutenberg.org/ebooks/11984
# Essays in Radical Empiricism: www.gutenberg.org/ebooks/32547
# The Analysis of Mind: www.gutenberg.org/ebooks/2529
# Mysticism and Logic and Other Essays: www.gutenberg.org/ebooks/25447
# Tractatus Logico-Philosophicus: www.gutenberg.org/ebooks/5740
# vol. 1: www.gutenberg.org/ebooks/26495
# vol. 1: www.gutenberg.org/ebooks/35420
# vol. 2: www.gutenberg.org/ebooks/35421
# 8th ed.: www.gutenberg.org/ebooks/27942
# Analysis of Mr. Mill's System of Logic: www.gutenberg.org/ebooks/30866
# Symbolic Logic: www.gutenberg.org/ebooks/28696
# The Game of Logic: www.gutenberg.org/ebooks/4763
# Logic, Inductive and Deductive: www.gutenberg.org/ebooks/31796
# Deductive Logic: www.gutenberg.org/ebooks/6560
# Logic: Deductive and Inductive: www.gutenberg.org/ebooks/18440
# Ion: www.gutenberg.org/ebooks/1635
# The Republic: www.gutenberg.org/ebooks/1497
# Poetics: www.gutenberg.org/ebooks/6763
# Butcher trans.: www.gutenberg.org/ebooks/1974
# audio: www.gutenberg.org/ebooks/20685
# The True, The Beautiful and The Good: www.gutenberg.org/ebooks/36208
# Aesthetical Essays of Friedrich Schiller: www.gutenberg.org/ebooks/6798
# Laughter: An Essay on the Meaning of the Comic: www.gutenberg.org/ebooks/4352
# Die Geburt der Tragödie: www.gutenberg.org/ebooks/7206
# The Case Of Wagner, Nietzsche Contra Wagner, and Selected Aphorisms: www.gutenberg.org/ebooks/25012
# Homer and Classical Philology: www.gutenberg.org/ebooks/18188
# The Principles of Aesthetics: www.gutenberg.org/ebooks/6366
# Ethics: www.gutenberg.org/ebooks/8438
# Literary and Philosophical Essays: French, German and Italian: www.gutenberg.org/ebooks/5637
# An Enquiry Concerning the Principles of Morals: www.gutenberg.org/ebooks/4320
# Ethics: www.gutenberg.org/ebooks/3800
# part 1: www.gutenberg.org/ebooks/919
# part 2: www.gutenberg.org/ebooks/920
# part 3: www.gutenberg.org/ebooks/948
# part 4: www.gutenberg.org/ebooks/971
# part 5: www.gutenberg.org/ebooks/975
# The Philosophy of the Moral Feelings: www.gutenberg.org/ebooks/22364
# Beyond Good and Evil: www.gutenberg.org/ebooks/4363
# audiobook: www.gutenberg.org/ebooks/19634
# Utilitarianism: www.gutenberg.org/ebooks/11224
# The English Utilitarians, Volume I: www.gutenberg.org/ebooks/27597
# Apology: www.gutenberg.org/ebooks/1656
# The Republic: www.gutenberg.org/ebooks/1497
# Politics: www.gutenberg.org/ebooks/6762
# The Prince: www.gutenberg.org/ebooks/1232
# audiobook: www.gutenberg.org/ebooks/26253
# Second Treatise of Government: www.gutenberg.org/ebooks/7370
# The Communist Manifesto: www.gutenberg.org/ebooks/61
# audiobook: www.gutenberg.org/ebooks/23905
# Selected Essays: www.gutenberg.org/ebooks/21565
# On Liberty: www.gutenberg.org/ebooks/34901
# Considerations on Representative Government: www.gutenberg.org/ebooks/5669
# Essays on some unsettled Questions of Political Economy: www.gutenberg.org/ebooks/12004
# Proposed Roads to Freedom: www.gutenberg.org/ebooks/690
# Political Ideals: www.gutenberg.org/ebooks/4776
# An Introduction to the Philosophy of Law: www.gutenberg.org/ebooks/32168
# Literary and Philosophical Essays: French, German and Italian: www.gutenberg.org/ebooks/5637
# Democracy and Education: an introduction to the philosophy of education: www.gutenberg.org/ebooks/852
# Mysticism and Logic and Other Essays: www.gutenberg.org/ebooks/25447
# Moral Principles in Education: www.gutenberg.org/ebooks/25172
# Euthyphro: www.gutenberg.org/ebooks/1642
# Dialogues Concerning Natural Religion: www.gutenberg.org/ebooks/4583
# Theologico-Political Treatise — Part 1: www.gutenberg.org/ebooks/989
# part 2: www.gutenberg.org/ebooks/990
# part 3: www.gutenberg.org/ebooks/991
# part 4: www.gutenberg.org/ebooks/992
# Mysticism and Logic and Other Essays: www.gutenberg.org/ebooks/25447
# Philosophy and Religion: Six Lectures Delivered at Cambridge: www.gutenberg.org/ebooks/21995
# Philosophical Letters of Frederich Schiller: www.gutenberg.org/ebooks/6799
# The Antichrist: www.gutenberg.org/ebooks/19322
#  Jewish History: an essay in the philosophy of history: www.gutenberg.org/ebooks/7836
# The Psychology of Nations: A Contribution to the Philosophy of History: www.gutenberg.org/ebooks/20814
# A History of Indian Philosophy, Volume 1: www.gutenberg.org/ebooks/12956
# The Religion of the Samurai: A Study of Zen Philosophy and Discipline in China and Japan: www.gutenberg.org/ebooks/5173
# Introduction to the Philosophy and Writings of Plato: www.gutenberg.org/ebooks/10214
# English Men of Letters: Bacon: www.gutenberg.org/ebooks/13888
# Achtundvierzig Briefe von Johann Gottlieb Fichte und seinen Verwandten by Fichte: www.gutenberg.org/ebooks/29530
# Autobiography: www.gutenberg.org/ebooks/10378
# Review of the Work of Mr John Stuart Mill Entitled, 'Examination of Sir William Hamilton's Philosophy.': www.gutenberg.org/ebooks/12002
# Critical Miscellanies: The Death of Mr. Mill & Mr. Mill's Autobiography: www.gutenberg.org/ebooks/20887
# English Men of Letters: Burke: www.gutenberg.org/ebooks/12922
# An Interpretation of Rudolf Eucken's Philosophy: www.gutenberg.org/ebooks/16835
# Bergson and His Philosophy: www.gutenberg.org/ebooks/5717
# A New Philosophy: Henri Bergson: www.gutenberg.org/ebooks/1347
# Critical Miscellanies: August Comte: www.gutenberg.org/ebooks/29033
# http://www.gutenberg.org/w/index.php?title=Philosophy_(Bookshelf)&oldid=18505: http://www.gutenberg.org/w/index.php?title=Philosophy_(Bookshelf)&oldid=18505
# Contact Info: wiki/Gutenberg:Contact_Information
# Why donate?: wiki/Gutenberg:Project_Gutenberg_Needs_Your_Donation
# Privacy policy: wiki/Gutenberg:Privacy_policy
# About Gutenberg: wiki/Gutenberg:About
# Disclaimers: wiki/Gutenberg:General_disclaimer

# %% [markdown]
# Note that the code above also makes use of the `re` library, to examine the form of the URLs and to get rid of unwanted characters.
#
# Once you have created a list of URLs using the method outlined above, you can also download all the texts that were found, using the `get()` method from `requests` library.

# %% [markdown]
# < [Regular expressions](Regular%20expressions.html) | [Table of contents](index.html) | [NLTK](NLTK.html) >
